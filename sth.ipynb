# %%
import fasttext as ft
from fasttext.util import download_model, reduce_model

#download_model("zh")
def run_once():
    mdl = ft.load_model("./ft_model/cc.zh.300.bin")
    mdl = reduce_model(mdl, 128)
    mdl.save_model("./ft_model/cczh128.bin")
#run_once()

# %%
mdl = ft.load_model("./ft_model/cczh128.bin")
# Out:
# ...
# 【

# %%
#print( _a := mdl.get_word_vector("盖子") , _b := mdl.get_word_vector("门"), )
#print(type(mdl.get_words()))
words: list[str] = mdl.get_words()      # !!! fuck!
print(len(words), words[:100])

# good?
# Out:
# 2000000 ['，', '的', '。', '</s>', '、', '是', '一', '在', '：', '了', '（', '）', "'", '和', '不', '有', '我', ',', ')', '(', '“', '”', '也', '人', '个', ':', '中', '.', '就', '他', '》', '《', '-', '你', '都', '上', '大', '！', '这', '为', '多', '与', '章', '「', '到', '」', '要', '？', '被', '而', '能', '等', '可以', '年', '；', '|', '以', '及', '之', '公司', '对', '中国', '很', '会', '小', '但', '我们', '最', '更', '/', '1', '三', '新', '自己', '可', '2', '或', '次', '好', '将', '第', '种', '她', '…', '3', '地', '對', '用', '工作', '下', '后', '由', '两', '使用', '还', '又', '您', '?', '其', '已']
